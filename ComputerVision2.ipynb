# %% [markdown]
# NAME:MIHIR CHAUBEY PRN-1032211021
# DIV:TYBTECH-AIML

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.io import imshow

# %%
image=cv2.imread('IMG1.png')
plt.imshow(image)

# %%
ret,mask=cv2.threshold(image,50,255,cv2.THRESH_BINARY)
plt.imshow(mask)
kernel= np.ones((5,5),np.uint8)

# %%
dilation=cv2.dilate(mask,kernel,iterations=2)
plt.imshow(dilation)

# %%
erosion=cv2.erode(mask,kernel,iterations=6)
plt.imshow(erosion)

# %%
dilation=cv2.dilate(erosion,kernel,iterations=2)
plt.imshow(dilation)

# %%
img=cv2.imread('IMG2.png')
plt.imshow(img)

# %%
ret,mask=cv2.threshold(img,50,255,cv2.THRESH_BINARY)
plt.imshow(mask)
kernel= np.ones((5,5),np.uint8)

# %%
opening=cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernel)
plt.imshow(opening)

# %%
closing=cv2.morphologyEx(img,cv2.MORPH_CLOSE,kernel)
plt.imshow(closing)

# %%
img3=cv2.imread('IMG3.png')
plt.imshow(img3)
kernel= np.ones((2,2),np.uint8)

# %%
mg = cv2.morphologyEx(mask,cv2.MORPH_GRADIENT,kernel)
plt.imshow(mg)

# %%
dilation1=cv2.dilate(img3,kernel,iterations=2)
plt.imshow(dilation1)

# %%
erosion1=cv2.erode(img3,kernel,iterations=6)
plt.imshow(erosion1)

# %%
image3=cv2.subtract(dilation,erosion)
plt.imshow(image3)

# %%
th  = cv2.morphologyEx(mask,cv2.MORPH_TOPHAT,kernel)
plt.imshow(th)
